# %%
import os

import numpy as np
import pandas as pd
import seaborn as sns

# %pylab inline
from pylab import rcParams
rcParams['figure.figsize'] = 10,5

sns.set(style="darkgrid")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ddata_dir = "data/transformed/"
res_df = pd.read_csv(ddata_dir+"res.csv")
res_df.head()
# Out:
#                    Case  Precision  Recall  F1-Score    AUC    Project
# 0          All features       0.98    0.94      0.96  0.894  Xerces2-j
# 1        Top 4 features       0.98    0.94      0.95  0.933  Xerces2-j
# 2  Product Metrics Only       0.98    0.94      0.95  0.933  Xerces2-j
# 3  Process Metrics Only       0.98    0.88      0.92  0.887  Xerces2-j
# 4  All features + SMOTE       0.98    0.94      0.96  0.894  Xerces2-j

# %%
rcParams['figure.figsize'] = 10,7
ax = sns.barplot(x="Case", y="AUC", hue="Project", data=res_df)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
res_df.groupby(["Case"]).mean().plot(kind="bar")

# %%
res_df.groupby(["Case"]).mean()
# Out:
#                         Precision  Recall  F1-Score     AUC
# Case
# All features                0.755   0.735     0.745  0.7040
# All features + SMOTE        0.755   0.725     0.740  0.7005
# Process Metrics Only        0.745   0.690     0.710  0.6865
# Product Metrics Only        0.800   0.770     0.780  0.7690
# Top 4 features              0.760   0.740     0.745  0.7285
# Top 4 features + SMOTE      0.755   0.730     0.740  0.7040
